# %%
import konlpy

# %%
from konlpy.tag from Okt
import re
import json
from collections import Counter
import matplotlib
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from matplotlib import font_manager
# Out:
#   Input In [2]
#     from konlpy.tag from Okt
#                     ^
# SyntaxError: invalid syntax

# %%
from konlpy.tag import Okt
import re
import json
from collections import Counterif
import matplotlib
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from matplotlib import font_manager

# %% [raw]
# file = 'etnews.kr_facebook_2016-01-01_2018-08-01_4차 산업혁명'
#
# data = json.loads(open(file+'.json', 'r', encoding='utf-8').read())
#
# message = ''
# for item in data:
#     if 'message' in item.keys():
#         message = message + re.sub(r'[^\w]',' ', item['message'])

# %%
nip = Okt()
message_N = nip.nouns(message)
count = Counter(message_N)
word_count = dict()
for tag, counts in count.most_common(80):
    if len(str(tag))>1:
        word_count[tag] = counts

sorted_key = sorted(word_count, key = word_count.get, reverse=True)
sorted_value = sorted(word_count.values(), reverse=True)

plt.bar(range(len(word_count)), sorted_value, align='center')
plt.xticks(range(len(word_count)), list(sorted_key), rotation='75')
plt.xlabel('keyword')
plt.ylabel('count')
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54785 (\N{HANGUL SYLLABLE HYEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
nip = Okt()
message_N = nip.nouns(message)
count = Counter(message_N)
word_count = dict()
for tag, counts in count.most_common(80):
    if len(str(tag))>1:
        word_count[tag] = counts

sorted_key = sorted(word_count, key = word_count.get, reverse=True)
sorted_value = sorted(word_count.values(), reverse=True)
font_path = 'C:/windows/fonts/malgun.ttf'
font_name = font_manager.FontProperties(fname=font_path).get_name()
matplotlib.rc('font', family=font_name)

plt.bar(range(len(word_count)), sorted_value, align='center')
plt.xticks(range(len(word_count)), list(sorted_key), rotation='75')
plt.xlabel('keyword')
plt.ylabel('count')
plt.show()
