# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (3.5.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.1.tar.gz (220 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: pillow in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Building wheels for collected packages: wordcloud
#   Building wheel for wordcloud (setup.py): started
#   Building wheel for wordcloud (setup.py): finished with status 'done'
#   Created wheel for wordcloud: filename=wordcloud-1.8.1-cp39-cp39-win_amd64.whl size=152050 sha256=6ea38bf49f8fbcc51faefc5012d8a64088960db231e3e39eeefa122b7159ceb5
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\f9\7a\dd\06ef8b5dfe5483f6204133c08eeb16c287cc2c05e290ae2fc0
# Successfully built wordcloud
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.1

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import pandas as pd
import glob
import re
from functools import reduce
from nltk.tokenize import word_tokenize
from ntlk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS, WordCloud
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [5], in <cell line: 6>()
#       4 from functools import reduce
#       5 from nltk.tokenize import word_tokenize
# ----> 6 from ntlk.corpus import stopwords
#       7 from nltk.stem import WordNetLemmatizer
#       8 from collections import Counter
#
# ModuleNotFoundError: No module named 'ntlk'

# %%
import pandas as pd
import glob
import re
from functools import reduce
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS, WordCloud

# %%
all_files = glob.glob('myCabinetExcelData*.xls')

# %%
all_files
# Out:
# ['myCabinetExcelData (1).xls',
#  'myCabinetExcelData (2).xls',
#  'myCabinetExcelData (3).xls',
#  'myCabinetExcelData (4).xls',
#  'myCabinetExcelData (5).xls',
#  'myCabinetExcelData (6).xls',
#  'myCabinetExcelData (7).xls',
#  'myCabinetExcelData (8).xls',
#  'myCabinetExcelData (9).xls',
#  'myCabinetExcelData.xls']

# %%
all_files_data = []

for file in all_files:
    data_frame = pd.read_excel(file)
    all_files_data.append(data_frame)
all_files_data[0]
# Out:
#     Unnamed: 0   번호                                                 제목  \
# 0          NaN    1  Online Analytical Processing for Business Inte...
# 1          NaN    2  Call for Special Issue Papers: Big Data Analyt...
# 2          NaN    3  Call for Special Issue Papers: Big Data in Bus...
# 3          NaN    4  Can Big Data Machines Analyze Stock Market Sen...
# 4          NaN    5                           Big Data for Social Good
# ..         ...  ...                                                ...
# 95         NaN   96  GSio: A programmatic interface for delivering ...
# 96         NaN   97  Innovative approaches to the Sustainable Devel...
# 97         NaN   98  Analytics of big geosocial media and crowdsour...
# 98         NaN   99  The role of big Earth data in understanding cl...
# 99         NaN  100  Stewardship and analysis of big Earth observat...
#
#                                                    저자                    출판사  \
# 0               Patel, Jigna Ashish; Sharma, Priyanka       Mary Ann Leibert
# 1   Balamurugan, S.; Muthu, Bala Anand; Peng, Shen...       Mary Ann Leibert
# 2                                    Nobanee, Haitham       Mary Ann Leibert
# 3                                             unknown       Mary Ann Leibert
# 4                                             unknown       Mary Ann Leibert
# ..                                                ...                    ...
# 95  Larraondo, Pablo R.; Pringle, Sean; Guo, Jian;...  John Wiley & Sons Ltd
# 96  Guo, Huadong; Liang, Dong; Chen, Fang; Shirazi...  John Wiley & Sons Ltd
# 97     Li, Songnian; Wachowicz, Monica; Fan, Hongchao  John Wiley & Sons Ltd
# 98                                        Jia, Gensuo  John Wiley & Sons Ltd
# 99                           Wang, Lizhe; Yan, Jining  John Wiley & Sons Ltd
#
#      출판일
# 0   2020
# 1   2020
# 2   2019
# 3   2014
# 4   2015
# ..   ...
# 95  2017
# 96  2021
# 97  2021
# 98  2020
# 99  2020
#
# [100 rows x 6 columns]

# %%
all_files_data_concat = pd.concat(all_files_data, axis = 0, ignore_index = True)
all_files_data_concat
# Out:
#      Unnamed: 0   번호                                                 제목  \
# 0           NaN    1  Online Analytical Processing for Business Inte...
# 1           NaN    2  Call for Special Issue Papers: Big Data Analyt...
# 2           NaN    3  Call for Special Issue Papers: Big Data in Bus...
# 3           NaN    4  Can Big Data Machines Analyze Stock Market Sen...
# 4           NaN    5                           Big Data for Social Good
# ..          ...  ...                                                ...
# 995         NaN   96     A Message from the Editor-in-Chief of Big Data
# 996         NaN   97  Big data and analytics: a data management pers...
# 997         NaN   98      Deep Learning on Big, Sparse, Behavioral Data
# 998         NaN   99  Toward Business Process Innovation in the Big ...
# 999         NaN  100  Overcoming Resistance to Big Data and Operatio...
#
#                                                     저자               출판사   출판일
# 0                Patel, Jigna Ashish; Sharma, Priyanka  Mary Ann Leibert  2020
# 1    Balamurugan, S.; Muthu, Bala Anand; Peng, Shen...  Mary Ann Leibert  2020
# 2                                     Nobanee, Haitham  Mary Ann Leibert  2019
# 3                                              unknown  Mary Ann Leibert  2014
# 4                                              unknown  Mary Ann Leibert  2015
# ..                                                 ...               ...   ...
# 995                                            unknown  Mary Ann Leibert  2017
# 996                                    Mittal, Prabhat      Inderscience  2020
# 997  De Cnudde, Sofie; Ramon, Yanou; Martens, David...  Mary Ann Leibert  2019
# 998                   Saide, Saide; Sheng, Margaret L.  Mary Ann Leibert  2020
# 999            Phillips-Wren, Gloria; McKniff, Sueanne  Mary Ann Leibert  2020
#
# [1000 rows x 6 columns]

# %%
all_files_data_concat.to_csv('riss_bigdata.csv', encoding='utf-8', index=False)

# %%
all_title = all_files_data_concat['제목']
all_title
# Out:
# 0      Online Analytical Processing for Business Inte...
# 1      Call for Special Issue Papers: Big Data Analyt...
# 2      Call for Special Issue Papers: Big Data in Bus...
# 3      Can Big Data Machines Analyze Stock Market Sen...
# 4                               Big Data for Social Good
#                              ...
# 995       A Message from the Editor-in-Chief of Big Data
# 996    Big data and analytics: a data management pers...
# 997        Deep Learning on Big, Sparse, Behavioral Data
# 998    Toward Business Process Innovation in the Big ...
# 999    Overcoming Resistance to Big Data and Operatio...
# Name: 제목, Length: 1000, dtype: object

# %%
stopWords = set(stopwords.words("english"))
lemma = WordNetLemmatizer()

# %%
words = []

for title in all_title : 
    EnWords = re.sub(r"[^a-zA-Z]+"," ",str(title))
    EnWordsToken = word_tokenize(EnWords.lower())
    EnWordsTokenStop = [w for w in EnWordsToken if w not in stopWords]
    EnWordsTokenStopLemma = [lemma.lemmatize(w) for w in EnWordsTokenStop]
    words.append(EnWordsTokenStopLemma)

# %%
print(words)
# Out:
# [['online', 'analytical', 'processing', 'business', 'intelligence', 'big', 'data'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'agricultural', 'disaster', 'management'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'business'], ['big', 'data', 'machine', 'analyze', 'stock', 'market', 'sentiment'], ['big', 'data', 'social', 'good'], ['call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education'], ['big', 'data', 'analysis', 'swimming', 'pool', 'impact', 'household', 'electric', 'intensity', 'san', 'antonio', 'texas'], ['stgi', 'spatio', 'temporal', 'grid', 'index', 'model', 'marine', 'big', 'data'], ['big', 'data', 'healthcare', 'opportunity', 'challenge'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'intelligent', 'system', 'cybersecurity'], ['big', 'data', 'predictive', 'analytics', 'health', 'care'], ['comparison', 'scalability', 'batch', 'big', 'data', 'processing', 'apache', 'spark', 'apache', 'flink'], ['ensemble', 'based', 'scalable', 'approach', 'intrusion', 'detection', 'using', 'big', 'data', 'framework'], ['big', 'data', 'application', 'guangzhou', 'restaurant', 'analysis'], ['internet', 'thing', 'based', 'optimized', 'routing', 'big', 'data', 'gathering', 'system', 'landslide', 'detection'], ['big', 'data', 'guide', 'understanding', 'climate', 'change', 'case', 'theory', 'guided', 'data', 'science'], ['national', 'survey', 'population', 'health', 'big', 'data', 'analytics', 'mobile', 'health', 'monitor'], ['common', 'big', 'data', 'challenge', 'overcome'], ['labor', 'economist', 'get', 'microscope', 'big', 'data', 'labor', 'market', 'analysis'], ['research', 'dilemma', 'behavioral', 'big', 'data'], ['call', 'special', 'issue', 'paper', 'cloud', 'computing', 'big', 'data', 'cognitive', 'iot'], ['call', 'special', 'issue', 'paper', 'big', 'scientific', 'data', 'machine', 'learning', 'science', 'engineering'], ['call', 'special', 'issue', 'paper', 'deep', 'learning', 'assisted', 'big', 'data', 'analytics', 'biomedical', 'application', 'digital', 'healthcare'], ['u', 'army', 'person', 'event', 'data', 'environment', 'military', 'civilian', 'big', 'data', 'enterprise'], ['medical', 'school', 'training', 'relate', 'practice', 'evidence', 'big', 'data'], ['call', 'paper', 'special', 'issue', 'computational', 'propaganda', 'political', 'big', 'data'], ['big', 'data', 'little', 'data', 'care', 'coordination', 'medicare', 'beneficiary', 'medigap', 'coverage'], ['using', 'big', 'data', 'understand', 'human', 'condition', 'kavli', 'human', 'project'], ['call', 'special', 'issue', 'paper', 'big', 'scientific', 'data', 'machine', 'learning', 'science', 'engineering'], ['intelligent', 'big', 'data', 'analysis', 'review'], ['big', 'data', 'analytics', 'framework', 'border', 'crossing', 'transportation'], ['health', 'big', 'data', 'analytics', 'current', 'perspective', 'challenge', 'potential', 'solution'], ['intelligent', 'big', 'data', 'analysis', 'review'], ['clustering', 'big', 'spatiotemporal', 'interval', 'data'], ['analyzing', 'big', 'smart', 'metering', 'data', 'towards', 'differentiated', 'user', 'service', 'sublinear', 'approach'], ['leveraging', 'big', 'data', 'analytics', 'case', 'kenyan', 'telecom'], ['agile', 'big', 'data', 'analytics', 'web', 'based', 'system', 'architecture', 'centric', 'approach'], ['health', 'big', 'data', 'analytics', 'current', 'perspective', 'challenge', 'potential', 'solution'], ['improved', 'big', 'data', 'stock', 'index', 'prediction', 'using', 'deep', 'learning', 'cnn', 'gru'], ['scalable', 'big', 'data', 'modelling'], ['guest', 'editorial', 'big', 'data', 'analytics', 'web'], ['guest', 'editorial', 'big', 'data', 'infrastructure'], ['guest', 'editorial', 'big', 'scholar', 'data', 'discovery', 'collaboration'], ['guest', 'editorial', 'big', 'data', 'analytics', 'web'], ['guest', 'editorial', 'big', 'scholar', 'data', 'discovery', 'collaboration'], ['speed', 'big', 'data', 'analytics', 'unveiling' ...

# %%
words2 = list(reduce(lambda x,y : x+y, words))
print(words2)
# Out:
# ['online', 'analytical', 'processing', 'business', 'intelligence', 'big', 'data', 'call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'agricultural', 'disaster', 'management', 'call', 'special', 'issue', 'paper', 'big', 'data', 'business', 'big', 'data', 'machine', 'analyze', 'stock', 'market', 'sentiment', 'big', 'data', 'social', 'good', 'call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education', 'big', 'data', 'analysis', 'swimming', 'pool', 'impact', 'household', 'electric', 'intensity', 'san', 'antonio', 'texas', 'stgi', 'spatio', 'temporal', 'grid', 'index', 'model', 'marine', 'big', 'data', 'big', 'data', 'healthcare', 'opportunity', 'challenge', 'call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'intelligent', 'system', 'cybersecurity', 'big', 'data', 'predictive', 'analytics', 'health', 'care', 'comparison', 'scalability', 'batch', 'big', 'data', 'processing', 'apache', 'spark', 'apache', 'flink', 'ensemble', 'based', 'scalable', 'approach', 'intrusion', 'detection', 'using', 'big', 'data', 'framework', 'big', 'data', 'application', 'guangzhou', 'restaurant', 'analysis', 'internet', 'thing', 'based', 'optimized', 'routing', 'big', 'data', 'gathering', 'system', 'landslide', 'detection', 'big', 'data', 'guide', 'understanding', 'climate', 'change', 'case', 'theory', 'guided', 'data', 'science', 'national', 'survey', 'population', 'health', 'big', 'data', 'analytics', 'mobile', 'health', 'monitor', 'common', 'big', 'data', 'challenge', 'overcome', 'labor', 'economist', 'get', 'microscope', 'big', 'data', 'labor', 'market', 'analysis', 'research', 'dilemma', 'behavioral', 'big', 'data', 'call', 'special', 'issue', 'paper', 'cloud', 'computing', 'big', 'data', 'cognitive', 'iot', 'call', 'special', 'issue', 'paper', 'big', 'scientific', 'data', 'machine', 'learning', 'science', 'engineering', 'call', 'special', 'issue', 'paper', 'deep', 'learning', 'assisted', 'big', 'data', 'analytics', 'biomedical', 'application', 'digital', 'healthcare', 'u', 'army', 'person', 'event', 'data', 'environment', 'military', 'civilian', 'big', 'data', 'enterprise', 'medical', 'school', 'training', 'relate', 'practice', 'evidence', 'big', 'data', 'call', 'paper', 'special', 'issue', 'computational', 'propaganda', 'political', 'big', 'data', 'big', 'data', 'little', 'data', 'care', 'coordination', 'medicare', 'beneficiary', 'medigap', 'coverage', 'using', 'big', 'data', 'understand', 'human', 'condition', 'kavli', 'human', 'project', 'call', 'special', 'issue', 'paper', 'big', 'scientific', 'data', 'machine', 'learning', 'science', 'engineering', 'intelligent', 'big', 'data', 'analysis', 'review', 'big', 'data', 'analytics', 'framework', 'border', 'crossing', 'transportation', 'health', 'big', 'data', 'analytics', 'current', 'perspective', 'challenge', 'potential', 'solution', 'intelligent', 'big', 'data', 'analysis', 'review', 'clustering', 'big', 'spatiotemporal', 'interval', 'data', 'analyzing', 'big', 'smart', 'metering', 'data', 'towards', 'differentiated', 'user', 'service', 'sublinear', 'approach', 'leveraging', 'big', 'data', 'analytics', 'case', 'kenyan', 'telecom', 'agile', 'big', 'data', 'analytics', 'web', 'based', 'system', 'architecture', 'centric', 'approach', 'health', 'big', 'data', 'analytics', 'current', 'perspective', 'challenge', 'potential', 'solution', 'improved', 'big', 'data', 'stock', 'index', 'prediction', 'using', 'deep', 'learning', 'cnn', 'gru', 'scalable', 'big', 'data', 'modelling', 'guest', 'editorial', 'big', 'data', 'analytics', 'web', 'guest', 'editorial', 'big', 'data', 'infrastructure', 'guest', 'editorial', 'big', 'scholar', 'data', 'discovery', 'collaboration', 'guest', 'editorial', 'big', 'data', 'analytics', 'web', 'guest', 'editorial', 'big', 'scholar', 'data', 'discovery', 'collaboration', 'speed', 'big', 'data', 'analytics', 'unveiling', 'storage', 'distribution', 'sub', 'datasets', 'parallel', 'computing', 'preserving', 'pri ...

# %%
count = Counter(words2)
count
# Out:
# Counter({'online': 15,
#          'analytical': 2,
#          'processing': 25,
#          'business': 24,
#          'intelligence': 20,
#          'big': 1117,
#          'data': 1241,
#          'call': 31,
#          'special': 36,
#          'issue': 48,
#          'paper': 29,
#          'analytics': 107,
#          'agricultural': 4,
#          'disaster': 6,
#          'management': 33,
#          'machine': 24,
#          'analyze': 2,
#          'stock': 4,
#          'market': 9,
#          'sentiment': 4,
#          'social': 17,
#          'good': 6,
#          'multimedia': 5,
#          'engineering': 12,
#          'education': 9,
#          'analysis': 86,
#          'swimming': 1,
#          'pool': 1,
#          'impact': 16,
#          'household': 1,
#          'electric': 4,
#          'intensity': 8,
#          'san': 1,
#          'antonio': 1,
#          'texas': 1,
#          'stgi': 1,
#          'spatio': 2,
#          'temporal': 3,
#          'grid': 6,
#          'index': 6,
#          'model': 47,
#          'marine': 1,
#          'healthcare': 15,
#          'opportunity': 28,
#          'challenge': 46,
#          'intelligent': 11,
#          'system': 55,
#          'cybersecurity': 3,
#          'predictive': 8,
#          'health': 34,
#          'care': 11,
#          'comparison': 2,
#          'scalability': 1,
#          'batch': 2,
#          'apache': 4,
#          'spark': 5,
#          'flink': 2,
#          'ensemble': 4,
#          'based': 99,
#          'scalable': 13,
#          'approach': 53,
#          'intrusion': 1,
#          'detection': 12,
#          'using': 61,
#          'framework': 34,
#          'application': 42,
#          'guangzhou': 1,
#          'restaurant': 1,
#          'internet': 17,
#          'thing': 15,
#          'optimized': 2,
#          'routing': 2,
#          'gathering': 3,
#          'landslide': 1,
#          'guide': 4,
#          'understanding': 11,
#          'climate': 2,
#          'change': 4,
#          'case': 15,
#          'theory': 5,
#          'guided': 1,
#          'science': 35,
#          'national': 5,
#          'survey': 19,
#          'population': 5,
#          'mobile': 10,
#          'monitor': 1,
#          'common': 2,
#          'overcome': 1,
#          'labor': 2,
#          'economist': 1,
#          'get': 2,
#          'microscope': 1,
#          'research': 32,
#          'dilemma': 1,
#          'behavioral': 3,
#          'cloud': 29,
#          'computing': 23,
#          'cognitive': 4,
#          'iot': 10,
#          'scientific': 9,
#          'learning': 46,
#          'deep': 12,
#          'assisted': 4,
#          'biomedical': 4,
#          'digital': 15,
#          'u': 9,
#          'army': 2,
#          'person': 1,
#          'event': 1,
#          'environment': 11,
#          'military': 1,
#          'civilian': 1,
#          'enterprise': 7,
#          'medical': 16,
#          'school': 4,
#          'training': 3,
#          'relate': 1,
#          'practice': 11,
#          'evidence': 8,
#          'computational': 8,
#          'propaganda': 3,
#          'political': 7,
#          'little': 11,
#          'coordination': 1,
#          'medicare': 1,
#          'beneficiary': 1,
#          'medigap': 1,
#          'coverage': 1,
#          'understand': 2,
#          'human': 10,
#          'condition': 2,
#          'kavli': 1,
#          'project': 6,
#          'review': 23,
#          'border': 1,
#          'crossing': 1,
#          'transportation': 8,
#          'current': 8,
#          'perspective': 24,
#          'potential': 11,
#          'solution': 13,
#          'clustering': 10,
#          'spatiotemporal': 1,
#          'interval': 3,
#          'analyzing': 6,
#          'smart': 28,
#          'metering': 2,
#          'towards': 11,
#          'differentiated': 1,
#          'user': 3,
#          'service': 21,
#          'sublinear': 1,
#          'leveraging': 9,
#          'kenyan': 1,
#          'telecom': 2,
#          'agile': 1,
#          'web': 10,
#          'architecture': 12,
#          'centric': 1,
#          'improved': 5,
#          'prediction': 16,
#          'cnn': 1,
#          'gru': 1,
#          'modelling': 3,
#          'guest': 12,
#          'editorial': 15,
#          'infrastructure': 12,
#          'scholar': 3,
#          'discovery': 13,
#          'collaboration': 6,
#          'speed': 1,
#          'unveiling': 1,
#          'storage': 9,
#          'distribution': 10,
#          'sub': 1,
#          'datasets': 2,
#          'parallel': 5,
#          'preserving': 3,
#          'privacy': 11,
#          'k': 9,
#          'anonymisation': 1,
#          'algorithm': 27,
#          'large': 14,
#          'scale': 12,
#          'spectral': 1,
#          'managing': 5,
#          'operation': 5,
#          'similarity': 2,
#          'overfitting': 1,
#          'continued': 3,
#          'availability': 1,
#          'assurance': 1,
#          'petuum': 1,
#          'new': 39,
#          'platform': 33,
#          'distributed': 19,
#          'perception': 3,
#          'independent': 3,
#          'financial': 10,
#          'advisor': 1,
#          'usefulness': 1,
#          'context': 9,
#          'decision': 18,
#          'making': 18,
#          'uk': 1,
#          'deduplication': 3,
#          'encrypted': 1,
#          'ieee': 2,
#          'transaction': 2,
#          'vol': 2,
#          'fast': 3,
#          'semantic': 6,
#          'composition': 2,
#          'five': 3,
#          'layer': 2,
#          'hybridisation': 1,
#          'classifier': 3,
#          'anomaly': 3,
#          'algorithmseer': 1,
#          'extracting': 3,
#          'searching': 1,
#          'scholarly': 4,
#          'nosql': 4,
#          'database': 10,
#          'quality': 10,
#          'driven': 68,
#          'consistency': 2,
#          'palopro': 1,
#          'knowledge': 13,
#          'extraction': 4,
#          'news': 4,
#          'feature': 6,
#          'selection': 7,
#          'efficient': 17,
#          'economic': 1,
#          'kvasir': 1,
#          'provision': 2,
#          'semantically': 2,
#          'relevant': 2,
#          'content': 6,
#          'thermal': 2,
#          'aware': 6,
#          'dvfs': 1,
#          'enabled': 9,
#          'task': 2,
#          'scheduling': 10,
#          'center': 8,
#          'structural': 3,
#          'balance': 2,
#          'e': 7,
#          'commerce': 3,
#          'recommendation': 6,
#          'rating': 3,
#          'hdm': 1,
#          'composable': 1,
#          'enhanced': 4,
#          'visualization': 7,
#          'method': 20,
#          'aid': 1,
#          'trajectory': 2,
#          'pattern': 9,
#          'recognition': 1,
#          'longitudinal': 2,
#          'fuzzy': 5,
#          'handling': 4,
#          'hierarchical': 1,
#          'image': 5,
#          'real': 20,
#          'time': 20,
#          'toward': 7,
#          'flexible': 3,
#          'metadata': 2,
#          'indexing': 1,
#          'trend': 9,
#          'extended': 2,
#          'granger': 1,
#          'causality': 1,
#          'air': 4,
#          'estimation': 6,
#          'heterogeneous': 6,
#          'urban': 6,
#          'dip': 1,
#          'svm': 2,
#          'kernel': 5,
#          'support': 13,
#          'vector': 3,
#          'taxi': 2,
#          'passenger': 1,
#          'demand': 4,
#          'modeling': 15,
#          'roving': 1,
#          'sensor': 7,
#          'network': 26,
#          'eeg': 1,
#          'seizure': 1,
#          'bci': 1,
#          'via': 8,
#          'resting': 1,
#          'state': 11,
#          'fmri': 1,
#          'functional': 1,
#          'connectivity': 1,
#          'preprocessing': 1,
#          'pipeline': 3,
#          'topological': 1,
#          'concentric': 1,
#          'value': 11,
#          'secure': 3,
#          'multi': 11,
#          'owner': 1,
#          'scheme': 6,
#          'monitoring': 12,
#          'camera': 1,
#          'surveillance': 2,
#          'video': 2,
#          'corporate': 3,
#          'governance': 5,
#          'fraud': 3,
#          'annual': 1,
#          'report': 3,
#          'development': 20,
#          'ethical': 2,
#          'concern': 3,
#          'reference': 2,
#          'introducing': 1,
#          'perform': 1,
#          'technology': 26,
#          'evolving': 2,
#          'role': 12,
#          'fpga': 1,
#          'classification': 9,
#          'max': 1,
#          'min': 1,
#          'fair': 1,
#          'resource': 6,
#          'allocation': 5,
#          'stream': 4,
#          'shared': 2,
#          'earth': 24,
#          'frontier': 4,
#          'information': 22,
#          'comprehensive': 3,
#          'view': 4,
#          'cube': 1,
#          'interoperability': 2,
#          'gsio': 1,
#          'programmatic': 1,
#          'interface': 1,
#          'delivering': 1,
#          'innovative': 1,
#          'sustainable': 17,
#          'goal': 12,
#          'geosocial': 1,
#          'medium': 13,
#          'crowdsourced': 1,
#          'stewardship': 1,
#          'observation': 6,
#          'geospatial': 3,
#          'semantics': 4,
#          'ontology': 2,
#          'graph': 5,
#          'facilitates': 1,
#          'generalized': 3,
#          'supervised': 2,
#          'produce': 1,
#          'provincial': 1,
#          'wetland': 1,
#          'inventory': 1,
#          'map': 5,
#          'google': 4,
#          'engine': 3,
#          'geo': 2,
#          'evaluating': 5,
#          'partnership': 1,
#          'increasing': 1,
#          'use': 23,
#          'australian': 1,
#          'visual': 4,
#          'open': 6,
#          'public': 10,
#          'transport': 2,
#          'performance': 21,
#          'greater': 1,
#          'sydney': 1,
#          'sentinel': 2,
#          'landsat': 2,
#          'imagery': 1,
#          'global': 8,
#          'settlement': 1,
#          'mapping': 7,
#          'way': 6,
#          'achieving': 1,
#          'belt': 2,
#          'road': 1,
#          'region': 3,
#          'spatial': 7,
#          'exploiting': 3,
#          'space': 5,
#          'first': 3,
#          'experience': 3,
#          'timescan': 1,
#          'chain': 6,
#          'utilization': 4,
#          'core': 3,
#          'processor': 4,
#          'many': 1,
#          'co': 2,
#          'supercomputer': 1,
#          'beacon': 1,
#          'geocomputation': 1,
#          'simulation': 3,
#          'wechat': 1,
#          'blood': 2,
#          'donation': 2,
#          'behavior': 9,
#          'study': 18,
#          'simd': 1,
#          'mcmc': 1,
#          'sampling': 4,
#          'bayesian': 3,
#          'educational': 3,
#          'improving': 3,
#          'shuffle': 1,
#          'phase': 4,
#          'hadoop': 4,
#          'reduce': 2,
#          'mining': 22,
#          'small': 17,
#          'sector': 6,
#          'bigger': 3,
#          'biggest': 3,
#          'repository': 2,
#          'balloon': 1,
#          'unprecedented': 1,
#          'level': 2,
#          'coping': 2,
#          'transforming': 6,
#          'insight': 10,
#          'nearest': 4,
#          'neighbor': 3,
#          'obtain': 1,
#          'forecasting': 6,
#          'meet': 5,
#          'formal': 1,
#          'practical': 4,
#          'novel': 7,
#          'paradigm': 3,
#          'organisation': 2,
#          'leverage': 3,
#          'maturity': 1,
#          'quantile': 1,
#          'regression': 3,
#          'divide': 2,
#          'conquer': 1,
#          'strategy': 8,
#          'statistical': 8,
#          'double': 1,
#          'log': 2,
#          'skew': 1,
#          'symmetric': 1,
#          'error': 6,
#          'always': 1,
#          'yield': 2,
#          'benefit': 7,
#          'discretization': 1,
#          'taxonomy': 1,
#          'process': 24,
#          'attribute': 1,
#          'designing': 2,
#          'operating': 1,
#          'mine': 3,
#          'result': 2,
#          'output': 1,
#          'automated': 1,
#          'slicing': 1,
#          'validation': 1,
#          'ai': 4,
#          'integration': 4,
#          'geographical': 1,
#          'build': 2,
#          'better': 3,
#          'em': 2,
#          'theme': 1,
#          'crime': 1,
#          'detailed': 1,
#          'prominent': 1,
#          'compression': 5,
#          'used': 5,
#          'reducing': 2,
#          'volume': 2,
#          'overview': 3,
#          'sharing': 8,
#          'electrophysiology': 2,
#          'recombine': 1,
#          'r': 9,
#          'high': 12,
#          'complexity': 1,
#          'collection': 3,
#          'gamma': 1,
#          'matrix': 2,
#          'summarize': 1,
#          'dense': 1,
#          'sparse': 4,
#          'set': 4,
#          'haery': 1,
#          'query': 3,
#          'accumulative': 1,
#          'dimensional': 3,
#          'revised': 1,
#          'pyramid': 1,
#          'assessment': 7,
#          'peer': 2,
#          'produced': 1,
#          'implicit': 2,
#          'wikipedia': 1,
#          'chicken': 1,
#          'swarm': 3,
#          'foraging': 1,
#          'belief': 2,
#          'improves': 1,
#          'international': 6,
#          'conference': 2,
#          'bigcomp': 1,
#          'applying': 6,
#          'kansei': 1,
#          'hotel': 1,
#          'cyber': 2,
#          'physical': 4,
#          'portfolio': 2,
#          'successful': 1,
#          'optimization': 23,
#          'done': 2,
#          'security': 15,
#          'criminal': 2,
#          'investigation': 3,
#          'mapreduce': 8,
#          'programming': 3,
#          'entity': 1,
#          'communication': 6,
#          'tool': 4,
#          'experimental': 3,
#          'evaluation': 4,
#          'status': 6,
#          'fusion': 4,
#          'academic': 2,
#          'librarian': 4,
#          'competency': 2,
#          'skill': 2,
#          'implementation': 7,
#          'library': 1,
#          'single': 2,
#          'cell': 4,
#          'transcriptomics': 1,
#          'grand': 2,
#          'acquired': 1,
#          'industrial': 8,
#          'multichannel': 1,
#          'wireless': 8,
#          'active': 1,
#          'control': 11,
#          'industry': 16,
#          'partner': 1,
#          'allina': 1,
#          'team': 5,
#          'catalyst': 2,
#          'garner': 1,
#          'tensor': 4,
#          'dimensionality': 1,
#          'reduction': 3,
#          'problem': 10,
#          'sdn': 1,
#          'coal': 1,
#          'fired': 1,
#          'power': 6,
#          'plant': 1,
#          'exploring': 9,
#          'fundamental': 1,
#          'memory': 6,
#          'michael': 2,
#          'buck': 2,
#          'talk': 1,
#          'living': 1,
#          'dream': 2,
#          'bioinformaticist': 1,
#          'emerging': 3,
#          'alternative': 2,
#          'warehouse': 4,
#          'china': 17,
#          'deal': 5,
#          'heavy': 1,
#          'tailed': 1,
#          'mongodb': 1,
#          'modular': 1,
#          'building': 7,
#          'city': 8,
#          'advanced': 6,
#          'phone': 1,
#          'compute': 2,
#          'mobility': 6,
#          'scenario': 3,
#          'future': 17,
#          'rule': 4,
#          'granularity': 1,
#          'path': 1,
#          'success': 3,
#          'banking': 1,
#          'integrated': 1,
#          'skyline': 1,
#          'computation': 3,
#          'holistic': 2,
#          'responding': 1,
#          'turbulence': 1,
#          'mass': 1,
#          'customization': 1,
#          'capability': 8,
#          'comparing': 1,
#          'world': 20,
#          'regional': 3,
#          'supply': 6,
#          'finance': 2,
#          'bibliometric': 4,
#          'watchdog': 1,
#          'name': 1,
#          'matching': 1,
#          'risk': 13,
#          'hyper': 1,
#          'convergent': 2,
#          'innovation': 11,
#          'straggler': 1,
#          'optimal': 2,
#          'rescheduling': 1,
#          'slow': 1,
#          'running': 1,
#          'lfcso': 1,
#          'lvq': 1,
#          'pso': 1,
#          'analysing': 3,
#          'repeat': 1,
#          'effect': 2,
#          'advancing': 2,
#          'stakeholder': 3,
#          'word': 1,
#          'mouth': 1,
#          'csr': 1,
#          'dynamic': 7,
#          'twitter': 3,
#          'updating': 1,
#          'correct': 1,
#          'measurement': 8,
#          'subdata': 1,
#          'mr': 2,
#          'plot': 1,
#          'distinguishing': 1,
#          'incremental': 4,
#          'design': 8,
#          'methodology': 4,
#          'barrier': 2,
#          'embedding': 1,
#          'factory': 2,
#          'sap': 1,
#          'consultant': 1,
#          'unlocking': 1,
#          'causal': 2,
#          'relation': 1,
#          'manufacturing': 7,
#          'firm': 6,
#          'consensus': 1,
#          'lime': 1,
#          'retail': 1,
#          'apriori': 1,
#          'predicting': 6,
#          'amazon': 1,
#          'product': 7,
#          'pcce': 1,
#          'personality': 1,
#          'communicative': 1,
#          'community': 4,
#          'bit': 1,
#          'oriented': 5,
#          'aggregation': 3,
#          'implication': 8,
#          'era': 31,
#          'direction': 2,
#          'broadcasting': 1,
#          'va': 1,
#          'store': 3,
#          'virtual': 2,
#          'approximate': 1,
#          'supporting': 2,
#          'repetitive': 1,
#          'genome': 2,
#          'sequence': 2,
#          'neighbour': 1,
#          'join': 2,
#          'theoretical': 7,
#          'ecosystem': 2,
#          'step': 1,
#          'nonlinear': 1,
#          'dimension': 4,
#          'uncertainty': 7,
#          'measure': 2,
#          'conflict': 1,
#          'dempster': 1,
#          'shafer': 1,
#          'suspicious': 1,
#          'tax': 1,
#          'evasion': 1,
#          'group': 4,
#          'v': 4,
#          'non': 5,
#          'simple': 2,
#          'pre': 1,
#          'semi': 1,
#          'automatic': 1,
#          'fact': 1,
#          'bias': 2,
#          'correction': 4,
#          'sample': 2,
#          'feasibility': 1,
#          'contextual': 2,
#          'federated': 1,
#          'recommender': 1,
#          'linked': 1,
#          'sequential': 1,
#          'localization': 1,
#          'telco': 1,
#          'effective': 2,
#          'clinical': 11,
#          'chunk': 1,
#          'sensing': 6,
#          'source': 1,
#          'recursive': 1,
#          'approximation': 5,
#          'recovery': 2,
#          'dataset': 1,
#          'sensory': 1,
#          'canonical': 1,
#          'correlation': 2,
#          'multiview': 1,
#          'skia': 1,
#          'textual': 1,
#          'emulated': 1,
#          'order': 3,
#          'identification': 5,
#          'series': 5,
#          'vecchia': 1,
#          'laplace': 1,
#          'gaussian': 2,
#          'factorization': 2,
#          'blind': 1,
#          'factor': 4,
#          'distrubted': 1,
#          'dws': 1,
#          'technique': 10,
#          'access': 6,
#          'competitive': 6,
#          'advantage': 4,
#          'car': 4,
#          'hailing': 1,
#          'eu': 1,
#          'law': 4,
#          'face': 2,
#          'shake': 1,
#          'transformation': 8,
#          'enriched': 1,
#          'simplified': 2,
#          'course': 3,
#          'given': 1,
#          'student': 6,
#          'expectation': 1,
#          'frame': 1,
#          'make': 5,
#          'friendly': 1,
#          'commentary': 1,
#          'mo': 2,
#          'orthopaedic': 1,
#          'generalizability': 1,
#          'oracle': 2,
#          'sparc': 2,
#          'accelerates': 1,
#          'recent': 4,
#          'integrate': 1,
#          'hardware': 2,
#          'acceleration': 1,
#          'software': 4,
#          'also': 2,
#          'enable': 3,
#          'working': 2,
#          'field': 6,
#          'augmented': 1,
#          'ethnography': 1,
#          'candidate': 3,
#          'interaction': 1,
#          'election': 2,
#          'ready': 2,
#          'hazy': 1,
#          'easier': 1,
#          'maintain': 1,
#          'racing': 1,
#          'unleash': 1,
#          'full': 1,
#          'latest': 2,
#          'gesch': 1,
#          'ftsmodelle': 1,
#          'die': 1,
#          'drei': 1,
#          'seiten': 1,
#          'der': 5,
#          'medaille': 1,
#          'bioinformatics': 2,
#          'workflow': 3,
#          'comparative': 3,
#          'technologien': 1,
#          'fahrzeugentwicklung': 1,
#          'cluster': 5,
#          'curation': 1,
#          'coming': 1,
#          'promise': 7,
#          'mitigation': 1,
#          'next': 10,
#          'generation': 10,
#          'question': 9,
#          'horizontal': 1,
#          'vertical': 1,
#          'discussion': 3,
#          'energy': 18,
#          'lesson': 4,
#          'assembling': 1,
#          'safety': 10,
#          'conceptual': 4,
#          'influencing': 2,
#          'spectrum': 2,
#          'g': 1,
#          'growth': 4,
#          'adaptive': 7,
#          'exception': 1,
#          'parallelized': 1,
#          'government': 6,
#          'incorporating': 1,
#          'smallholder': 2,
#          'palm': 1,
#          'oil': 5,
#          'production': 4,
#          'x': 3,
#          'ray': 1,
#          'contrast': 1,
#          'imaging': 2,
#          'battery': 1,
#          'recycling': 1,
#          'vehicle': 6,
#          'streaming': 1,
#          'concept': 3,
#          'drift': 1,
#          'drive': 2,
#          'parking': 1,
#          'policy': 9,
#          'adherence': 1,
#          'meter': 2,
#          'limit': 1,
#          'washington': 1,
#          'c': 4,
#          'anwendungsf': 1,
#          'lle': 1,
#          'methodisch': 1,
#          'erarbeiten': 1,
#          'critical': 6,
#          'literature': 5,
#          'multiperspective': 1,
#          'screening': 3,
#          'bregman': 1,
#          'divergence': 1,
#          'three': 2,
#          'aerial': 2,
#          'laser': 1,
#          'scanning': 3,
#          'type': 2,
#          'gene': 4,
#          'expression': 2,
#          'advance': 5,
#          'highlight': 1,
#          'revamp': 1,
#          'toxicology': 1,
#          'charge': 1,
#          'consumption': 3,
#          'mechanism': 2,
#          'reflection': 1,
#          'electron': 1,
#          'diffraction': 1,
#          'epitaxial': 1,
#          'film': 1,
#          'realm': 1,
#          'possibility': 2,
#          'emergence': 2,
#          'capital': 2,
#          'informatics': 4,
#          'smarter': 1,
#          'prevention': 3,
#          'sphps': 1,
#          'transfer': 2,
#          'maximizing': 1,
#          'throughput': 2,
#          'interactive': 2,
#          'quantification': 1,
#          'variation': 1,
#          'satellite': 2,
#          'yearly': 1,
#          'aiaa': 1,
#          'edge': 3,
#          'biomarkers': 1,
#          'dynamical': 1,
#          'drug': 8,
#          'sensitivity': 2,
#          'resistance': 3,
#          'individual': 2,
#          'formation': 1,
#          'entropy': 1,
#          'alloy': 1,
#          'protein': 2,
#          'structure': 2,
#          'metagenomics': 1,
#          'give': 1,
#          'boost': 3,
#          'carbon': 2,
#          'emission': 1,
#          'walkable': 1,
#          'green': 4,
#          'stem': 2,
#          'tissue': 1,
#          'vision': 2,
#          'unique': 1,
#          'ecology': 4,
#          'lead': 1,
#          'increased': 2,
#          'animal': 1,
#          'movement': 1,
#          'struggle': 1,
#          'birthing': 1,
#          'pain': 3,
#          'researcher': 2,
#          'say': 2,
#          'selbstlernende': 1,
#          'analysen': 1,
#          'f': 5,
#          'intelligentes': 1,
#          'energiemanagement': 1,
#          'predict': 2,
#          'target': 3,
#          'molecule': 1,
#          'accelerate': 1,
#          'streetlytics': 1,
#          'estate': 1,
#          'dissemination': 2,
#          'south': 2,
#          'korea': 2,
#          'rhetoric': 1,
#          'relating': 1,
#          'united': 5,
#          'capturing': 2,
#          'visitor': 1,
#          'activity': 3,
#          'flow': 5,
#          'island': 1,
#          'country': 1,
#          'thematic': 1,
#          'landscape': 2,
#          'ethic': 3,
#          'sears': 1,
#          'away': 1,
#          'contemporary': 1,
#          'french': 1,
#          'politics': 5,
#          'blockwise': 1,
#          'gradient': 1,
#          'tracking': 4,
#          'objective': 1,
#          'persisting': 1,
#          'measuring': 1,
#          'relationship': 6,
#          'app': 1,
#          'usage': 2,
#          'broadcast': 1,
#          'fat': 1,
#          'tree': 3,
#          'device': 9,
#          'worker': 3,
#          'pharmaceutical': 5,
#          'intervention': 1,
#          'covid': 5,
#          'pandemic': 2,
#          'surface': 2,
#          'fitting': 2,
#          'improve': 10,
#          'aircraft': 3,
#          'newton': 1,
#          'merton': 1,
#          'job': 2,
#          'outlook': 1,
#          'encouraging': 1,
#          'gm': 1,
#          ...})

# %%
word_count = dict()

# %%
for tag, counts in count.most_common(50):
    if(len(str(tag))>1):
        word_count[tag] = counts
        print("%s : %d" % (tag, counts))
# Out:
# data : 1241
# big : 1117
# analytics : 107
# based : 99
# analysis : 86
# driven : 68
# using : 61
# system : 55
# approach : 53
# issue : 48
# model : 47
# challenge : 46
# learning : 46
# application : 42
# new : 39
# special : 36
# science : 35
# health : 34
# framework : 34
# management : 33
# platform : 33
# research : 32
# call : 31
# era : 31
# paper : 29
# cloud : 29
# opportunity : 28
# smart : 28
# algorithm : 27
# network : 26
# technology : 26
# processing : 25
# business : 24
# machine : 24
# perspective : 24
# earth : 24
# process : 24
# computing : 23
# review : 23
# use : 23
# optimization : 23
# information : 22
# mining : 22
# service : 21
# performance : 21
# intelligence : 20
# method : 20
# real : 20
# time : 20
# development : 20

# %%
sorted_keys = sorted(word_count, key = word_count.get, reverse = True)
sorted_Values = sorted(word_count.values(), reverse = True)
plt.bar(range(len(word_count)), sorted_Values, align = 'center')

plt.xticks(range(len(word_count)), list(sorted_keys), rotation='85')
plt.show()

# %%
all_files_data_concat['doc_count'] =  0
summary_year = all_files_data_concat.groupby('출판일', as_index = False)['doc_count'].count()
summary_year
# Out:
#      출판일  doc_count
# 0   1995          1
# 1   2003          1
# 2   2004          1
# 3   2006          1
# 4   2009          1
# 5   2011          5
# 6   2012         19
# 7   2013         53
# 8   2014        133
# 9   2015        106
# 10  2016        122
# 11  2017        139
# 12  2018        122
# 13  2019         91
# 14  2020        103
# 15  2021         83
# 16  2022         19

# %%
plt.figure(figsize = (12,5))
plt.xlabel("year")
plt.ylabel("doc-count")
plt.grid(True)

plt.plot(range(len(summary_year)), summary_year['doc_count'])
plt.xticks(range(len(summary_year)), [text for text in summary_year['출판일']])
plt.show()

# %%
stopwords = set(STOPWORDS)
ws = WordCloud(background_color = 'ivory')
